# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("desktop/zeyad.csv")
df
# Out:
#     Manufacturer       Model Name   Category  Screen Size  \
# 0          Apple      MacBook Pro  Ultrabook         13.3
# 1          Apple      Macbook Air  Ultrabook         13.3
# 2             HP           250 G6   Notebook         15.6
# 3          Apple      MacBook Pro  Ultrabook         15.4
# 4          Apple      MacBook Pro  Ultrabook         13.3
# ..           ...              ...        ...          ...
# 934         Dell   Latitude E7470  Ultrabook         14.0
# 935      Toshiba  Tecra A40-C-1DF   Notebook         14.0
# 936         Asus        Rog Strix     Gaming         17.3
# 937           HP      Probook 450   Notebook         15.6
# 938       Lenovo    ThinkPad T460   Notebook         14.0
#
#                                  Screen                          CPU   RAM  \
# 0    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8.0
# 1                              1440x900         Intel Core i5 1.8GHz   8.0
# 2                     Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8.0
# 3    IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz  16.0
# 4    IPS Panel Retina Display 2560x1600         Intel Core i5 3.1GHz   8.0
# ..                                  ...                          ...   ...
# 934               Touchscreen 2560x1440   Intel Core i7 6600U 2.6GHz   8.0
# 935                   Full HD 1920x1080   Intel Core i5 6200U 2.3GHz   8.0
# 936                   Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16.0
# 937         IPS Panel Full HD 1920x1080  Intel Core i5 7200U 2.70GHz   8.0
# 938                            1366x768   Intel Core i5 6200U 2.3GHz   4.0
#
#                               GPU Operating System Operating System Version  \
# 0    Intel Iris Plus Graphics 640            macOS                       10
# 1          Intel HD Graphics 6000            macOS                       10
# 2           Intel HD Graphics 620            No OS                       10
# 3              AMD Radeon Pro 455            macOS                       10
# 4    Intel Iris Plus Graphics 650            macOS                       10
# ..                            ...              ...                      ...
# 934         Intel HD Graphics 520          Windows                       10
# 935         Intel HD Graphics 520          Windows                       10
# 936       Nvidia GeForce GTX 1060          Windows                       10
# 937          Nvidia GeForce 930MX          Windows                       10
# 938         Intel HD Graphics 520          Windows                        7
#
#      Weight  HDD  SSD  Hybrid   FS   price_ln
# 0      1.37    0  128       0    0  16.293101
# 1      1.34    0    0       0  128  15.894124
# 2      1.86    0  256       0    0  15.447277
# 3      1.83    0  512       0    0  16.931822
# 4      1.37    0  256       0    0  16.590447
# ..      ...  ...  ...     ...  ...        ...
# 934    1.50    0  256       0    0  16.675126
# 935    1.95    0  256       0    0  16.166177
# 936    2.73    1  256       0    0  16.718454
# 937    2.04    1  128       0    0  15.979439
# 938    1.70    0    0     508    0  16.002661
#
# [939 rows x 16 columns]

# %% [markdown]
# # 1-what is the most expensive laptop on store?

# %%
df[df['price_ln']==df['price_ln'].max()]
# Out:
#     Manufacturer Model Name Category  Screen Size             Screen  \
# 627        Razer  Blade Pro   Gaming         14.0  Full HD 1920x1080
#
#                              CPU   RAM                      GPU  \
# 627  Intel Core i7 7700HQ 2.8GHz  16.0  Nvidia GeForce GTX 1060
#
#     Operating System Operating System Version  Weight  HDD  SSD  Hybrid  FS  \
# 627          Windows                       10    1.95    0  256       0   0
#
#       price_ln
# 627  16.955789

# %%
sns.set(rc={'figure.figsize':[10,10]},font_scale=1.2)

sns.countplot(y='Manufacturer',data=df)
# Out:
# <Axes: xlabel='count', ylabel='Manufacturer'>

# %% [markdown]
# # 2- what is the average Price of Manufacturer?

# %%
df.groupby('Manufacturer').mean()['price_ln']
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10280\3968996808.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Manufacturer').mean()['price_ln']
# Manufacturer
# Acer         15.441452
# Apple        16.410050
# Asus         15.828233
# Chuwi        14.801338
# Dell         15.990929
# Fujitsu      15.737237
# Google       16.492327
# HP           15.852395
# Huawei       16.352743
# LG           16.739083
# Lenovo       15.851047
# MSI          16.484999
# Mediacom     14.762869
# Microsoft    16.422356
# Razer        16.771841
# Samsung      16.291070
# Toshiba      16.097911
# Vero         14.529605
# Xiaomi       16.113316
# Name: price_ln, dtype: float64

# %% [markdown]
# # 3-What's the 5 top highest storage for Apple?

# %%
df[df['Manufacturer']=='Apple'].sort_values(by='SSD',ascending=False).head(5)
# Out:
#     Manufacturer   Model Name   Category  Screen Size  \
# 3          Apple  MacBook Pro  Ultrabook         15.4
# 80         Apple  MacBook 12"  Ultrabook         12.0
# 242        Apple  MacBook Pro  Ultrabook         13.3
# 263        Apple  MacBook Pro  Ultrabook         13.3
# 4          Apple  MacBook Pro  Ultrabook         13.3
#
#                                  Screen                   CPU   RAM  \
# 3    IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16.0
# 80   IPS Panel Retina Display 2304x1440  Intel Core i5 1.3GHz   8.0
# 242  IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz   8.0
# 263  IPS Panel Retina Display 2560x1600  Intel Core i5 2.9GHz   8.0
# 4    IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz   8.0
#
#                               GPU Operating System Operating System Version  \
# 3              AMD Radeon Pro 455            macOS                       10
# 80          Intel HD Graphics 615            macOS                       10
# 242  Intel Iris Plus Graphics 650            macOS                       10
# 263       Intel Iris Graphics 550            macOS                       10
# 4    Intel Iris Plus Graphics 650            macOS                       10
#
#      Weight  HDD  SSD  Hybrid  FS   price_ln
# 3      1.83    0  512       0   0  16.931822
# 80     0.92    0  512       0   0  16.412772
# 242    1.37    0  512       0   0  16.713612
# 263    1.37    0  512       0   0  16.673046
# 4      1.37    0  256       0   0  16.590447

# %% [markdown]
# # 4-Which model that has the highest screen size ?

# %%
df[df['Screen Size']==df['Screen Size'].max()]
# Out:
#     Manufacturer                            Model Name            Category  \
# 28            HP                           ProBook 470            Notebook
# 31            HP  17-ak001nv (A6-9220/4GB/500GB/Radeon            Notebook
# 36          Dell                         Inspiron 5770            Notebook
# 43          Dell                         Inspiron 7773  2 in 1 Convertible
# 46          Asus                             Rog Strix              Gaming
# ..           ...                                   ...                 ...
# 883          MSI                            GE72VR 6RF              Gaming
# 905           HP                        Omen 17-W006na              Gaming
# 906         Asus  X751SV-TY001T (N3710/4GB/1TB/GeForce            Notebook
# 913         Dell                         Insprion 5767            Notebook
# 936         Asus                             Rog Strix              Gaming
#
#      Screen Size                           Screen  \
# 28          17.3                Full HD 1920x1080
# 31          17.3                Full HD 1920x1080
# 36          17.3      IPS Panel Full HD 1920x1080
# 43          17.3  Full HD / Touchscreen 1920x1080
# 46          17.3                Full HD 1920x1080
# ..           ...                              ...
# 883         17.3                Full HD 1920x1080
# 905         17.3      IPS Panel Full HD 1920x1080
# 906         17.3                         1600x900
# 913         17.3                         1600x900
# 936         17.3                Full HD 1920x1080
#
#                                       CPU   RAM                         GPU  \
# 28             Intel Core i5 8250U 1.6GHz   8.0        Nvidia GeForce 930MX
# 31              AMD A6-Series 9220 2.5GHz   4.0              AMD Radeon 530
# 36             Intel Core i5 8250U 1.6GHz   8.0              AMD Radeon 530
# 43             Intel Core i5 8250U 1.6GHz  12.0        Nvidia GeForce 150MX
# 46                    AMD Ryzen 1700 3GHz   8.0           AMD Radeon RX 580
# ..                                    ...   ...                         ...
# 883           Intel Core i7 7700HQ 2.8GHz  16.0  Nvidia GeForce GTX 1050 Ti
# 905           Intel Core i5 6300HQ 2.3GHz   8.0     Nvidia GeForce GTX 965M
# 906  Intel Pentium Quad Core N3710 1.6GHz   4.0        Nvidia GeForce 920MX
# 913            Intel Core i3 6006U 2.0GHz   4.0          AMD Radeon R7 M445
# 936           Intel Core i7 7700HQ 2.8GHz  16.0     Nvidia GeForce GTX 1060
#
#     Operating System Operating System Version  Weight  HDD  SSD  Hybrid  FS  \
# 28           Windows                       10    2.50    1    0       0   0
# 31           Windows                       10    2.71  500    0       0   0
# 36           Windows                       10    2.80    1  128       0   0
# 43           Windows                       10    2.77    1    0       0   0
# 46           Windows                       10    3.20    1  256       0   0
# ..               ...                      ...     ...  ...  ...     ...  ..
# 883          Windows                       10    2.70    1  256       0   0
# 905          Windows                       10    2.75    1  128       0   0
# 906          Windows                       10    2.80    1    0       0   0
# 913          Windows                       10    2.36    1    0       0   0
# 936          Windows                       10    2.73    1  256       0   0
#
#       price_ln
# 28   15.890848
# 31   15.177407
# 36   15.979439
# 43   15.999662
# 46   16.262257
# ..         ...
# 883  16.470041
# 905  16.336420
# 906  15.365784
# 913  15.583631
# 936  16.718454
#
# [109 rows x 16 columns]

# %%
sns.boxplot(x='Screen Size',data=df)
# Out:
# <Axes: xlabel='Screen Size'>

# %% [markdown]
# # 5-is there's a correlation between RAM and Price ?

# %%
col1=df['RAM']

col2=df['price_ln']

corr=col1.corr(col2)

print("corrleation between RAM and Price is:",corr)
# Out:
# corrleation between RAM and Price is: 0.6903190192699059

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10280\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # 6-what is the 10 lowest price?

# %%
df.nsmallest(10, 'price_ln')
# Out:
#     Manufacturer                            Model Name  Category  Screen Size  \
# 19          Asus                       Vivobook E200HA   Netbook         11.6
# 30          Asus  E402WA-GA010T (E2-6110/2GB/32GB/W10)  Notebook         14.0
# 283         Acer                  Chromebook C910-C2ST  Notebook         15.6
# 762         Vero             K146 (N3350/4GB/32GB/W10)  Notebook         14.0
# 539         Asus  A541NA-GO342 (N3350/4GB/500GB/Linux)  Notebook         15.6
# 66            HP                     Stream 14-AX040wm  Notebook         14.0
# 606     Mediacom                         SmartBook 140  Notebook         14.0
# 29         Chuwi                         LapBook 15.6"  Notebook         15.6
# 502         Asus                          VivoBook E12   Netbook         11.6
# 471        Chuwi                          Lapbook 15,6  Notebook         15.6
#
#                 Screen                                   CPU  RAM  \
# 19            1366x768           Intel Atom x5-Z8350 1.44GHz  2.0
# 30            1366x768           AMD E-Series E2-6110 1.5GHz  2.0
# 283           1366x768  Intel Celeron Dual Core 3205U 1.5GHz  2.0
# 762          1920x1080  Intel Celeron Dual Core N3350 1.1GHz  4.0
# 539           1366x768  Intel Celeron Dual Core N3350 1.1GHz  4.0
# 66            1366x768  Intel Celeron Dual Core N3060 1.6GHz  4.0
# 606  Full HD 1920x1080           Intel Atom x5-Z8350 1.44GHz  2.0
# 29   Full HD 1920x1080           Intel Atom x5-Z8300 1.44GHz  4.0
# 502           1366x768  Intel Celeron Dual Core N3350 1.1GHz  2.0
# 471  Full HD 1920x1080           Intel Atom x5-Z8350 1.44GHz  4.0
#
#                        GPU Operating System Operating System Version  Weight  \
# 19   Intel HD Graphics 400          Windows                       10    0.98
# 30           AMD Radeon R2          Windows                       10    1.65
# 283      Intel HD Graphics        Chrome OS                       10    2.19
# 762  Intel HD Graphics 500          Windows                       10    1.22
# 539  Intel HD Graphics 500            Linux                       10    2.00
# 66   Intel HD Graphics 400          Windows                       10    1.44
# 606      Intel HD Graphics          Windows                       10    1.40
# 29       Intel HD Graphics          Windows                       10    1.89
# 502  Intel HD Graphics 500          Windows                       10    1.10
# 471      Intel HD Graphics          Windows                       10    1.89
#
#      HDD  SSD  Hybrid  FS   price_ln
# 19     0    0       0  32  14.349882
# 30     0    0       0  32  14.386212
# 283    0   16       0   0  14.386212
# 762    0    0       0  32  14.405621
# 539  500    0       0   0  14.504553
# 66     0   32       0   0  14.526629
# 606    0    0       0  32  14.569371
# 29     0    0       0  64  14.594125
# 502    0    0       0  32  14.594165
# 471    0    0       0  64  14.609958

# %% [markdown]
# # 7-how many laptops that have weight > 4.4kg ?

# %%
df[df['Weight']>4.4]
# Out:
#     Manufacturer    Model Name  Category  Screen Size  \
# 219         Dell  Alienware 17    Gaming         17.3
# 444         Dell  Alienware 17  Notebook         17.3
# 566          MSI     GT80S 6QE    Gaming         17.3
#
#                           Screen                          CPU   RAM  \
# 219  IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16.0
# 444  IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.7GHz   8.0
# 566            Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz  16.0
#
#                          GPU Operating System Operating System Version  \
# 219  Nvidia GeForce GTX 1060          Windows                       10
# 444  Nvidia GeForce GTX 1060          Windows                       10
# 566  Nvidia GeForce GTX 980M          Windows                       10
#
#      Weight  HDD  SSD  Hybrid  FS   price_ln
# 219    4.42    1  256       0   0  16.899335
# 444    4.42    1    0       0   0  16.716549
# 566    4.50    1  128       0   0  16.854652

# %% [markdown]
# # 8- what is the first 10 laptops that in Gaming Category and avg of its Price?

# %%
gaming_model = df[df['Category'] == 'Gaming'].head(10)

avg_price = gaming_model['price_ln'].mean()

print("Gaming models and their average price:")

print(gaming_model[['Manufacturer','Category', 'price_ln']])

print("Average price of gaming models:", avg_price)
# Out:
# Gaming models and their average price:
#    Manufacturer Category   price_ln
# 20       Lenovo   Gaming  15.999662
# 40         Dell   Gaming  16.405461
# 46         Asus   Gaming  16.262257
# 57          MSI   Gaming  16.896342
# 68         Asus   Gaming  15.948316
# 72          MSI   Gaming  16.091417
# 74         Asus   Gaming  15.948316
# 84         Dell   Gaming  16.300026
# 87         Asus   Gaming  16.371536
# 89         Asus   Gaming  15.642558
# Average price of gaming models: 16.18658918814475

# %% [markdown]
# # 9-Which model that his Hyprid not equal 0 ?

# %%
diff_model = df[df['Hybrid'] != 0]

print(diff_model[['Manufacturer','Model Name','Hybrid']])
# Out:
#     Manufacturer     Model Name  Hybrid
# 150         Dell  Inspiron 7567       1
# 938       Lenovo  ThinkPad T460     508

# %% [markdown]
# # 10-how many laptops that have price > 16.9k ?

# %%
df[df['price_ln']>16.9]
# Out:
#     Manufacturer      Model Name            Category  Screen Size  \
# 3          Apple     MacBook Pro           Ultrabook         15.4
# 251          MSI     GT73EVR 7RE              Gaming         17.3
# 266       Lenovo     ThinkPad X1  2 in 1 Convertible         14.0
# 303         Dell          XPS 13           Ultrabook         13.3
# 380       Lenovo     ThinkPad X1  2 in 1 Convertible         14.0
# 437    Microsoft  Surface Laptop           Ultrabook         13.5
# 627        Razer       Blade Pro              Gaming         14.0
# 670       Lenovo     ThinkPad X1  2 in 1 Convertible         14.0
# 789         Dell    Alienware 17              Gaming         17.3
# 793       Lenovo     Thinkpad X1           Ultrabook         14.0
# 825           HP  EliteBook x360  2 in 1 Convertible         13.3
#
#                                             Screen  \
# 3               IPS Panel Retina Display 2880x1800
# 251                              Full HD 1920x1080
# 266                          Touchscreen 2560x1440
# 303  IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 380                          Touchscreen 2560x1440
# 437                          Touchscreen 2256x1504
# 627                              Full HD 1920x1080
# 670                          Touchscreen 2560x1440
# 789                    IPS Panel Full HD 1920x1080
# 793                    IPS Panel Full HD 1920x1080
# 825                Full HD / Touchscreen 1920x1080
#
#                              CPU   RAM                           GPU  \
# 3           Intel Core i7 2.7GHz  16.0            AMD Radeon Pro 455
# 251  Intel Core i7 7700HQ 2.8GHz  16.0       Nvidia GeForce GTX 1070
# 266   Intel Core i7 6600U 2.6GHz  16.0         Intel HD Graphics 520
# 303   Intel Core i7 8550U 1.8GHz  16.0        Intel UHD Graphics 620
# 380   Intel Core i7 7500U 2.7GHz  16.0         Intel HD Graphics 620
# 437   Intel Core i7 7660U 2.5GHz  16.0  Intel Iris Plus Graphics 640
# 627  Intel Core i7 7700HQ 2.8GHz  16.0       Nvidia GeForce GTX 1060
# 670   Intel Core i7 7500U 2.7GHz   8.0         Intel HD Graphics 620
# 789  Intel Core i7 7700HQ 2.8GHz  16.0       Nvidia GeForce GTX 1060
# 793   Intel Core i7 7500U 2.7GHz   8.0         Intel HD Graphics 620
# 825   Intel Core i7 7600U 2.8GHz   8.0         Intel HD Graphics 620
#
#     Operating System Operating System Version  Weight  HDD  SSD  Hybrid  FS  \
# 3              macOS                       10    1.83    0  512       0   0
# 251          Windows                       10    4.14    1  512       0   0
# 266          Windows                       10    1.36    0  512       0   0
# 303          Windows                       10    1.21    0    1       0   0
# 380          Windows                       10    1.42    0  512       0   0
# 437          Windows                     10 S    1.25    0  512       0   0
# 627          Windows                       10    1.95    0  256       0   0
# 670          Windows                       10    1.42    0  256       0   0
# 789          Windows                       10    4.36    1  128       0   0
# 793          Windows                       10    1.13    0  512       0   0
# 825          Windows                       10    1.28    0  256       0   0
#
#       price_ln
# 3    16.931822
# 251  16.916553
# 266  16.916553
# 303  16.916553
# 380  16.920547
# 437  16.951934
# 627  16.955789
# 670  16.952320
# 789  16.918959
# 793  16.916553
# 825  16.940279

# %% [markdown]
# # 11-What is the relationship between laptop screen size and weight?

# %%
col1=df['Weight']

col2=df['Screen Size']

corr=col1.corr(col2)

print("corrleation between Manufacturer and Screen Size is:",corr)
# Out:
# corrleation between Manufacturer and Screen Size is: 0.841704956303566

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10280\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # 12-What is the average weight of laptops in the dataset?

# %%
df.groupby('Manufacturer').mean()['Weight']
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10280\208790635.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Manufacturer').mean()['Weight']
# Manufacturer
# Acer         2.108795
# Apple        1.378750
# Asus         2.114746
# Chuwi        1.726667
# Dell         2.040093
# Fujitsu      2.200000
# Google       1.100000
# HP           1.968588
# Huawei       1.050000
# LG           1.050000
# Lenovo       1.959000
# MSI          2.608065
# Mediacom     1.337143
# Microsoft    1.251333
# Razer        1.620000
# Samsung      1.336250
# Toshiba      1.695789
# Vero         1.260000
# Xiaomi       1.620000
# Name: Weight, dtype: float64

# %% [markdown]
# # 13-how many laptops that have 13.5" screen size ?

# %%
Model = df[df['Screen Size'] == 13.5]

print(Model[['Manufacturer','Screen Size']])
# Out:
#     Manufacturer  Screen Size
# 69     Microsoft         13.5
# 103    Microsoft         13.5
# 437    Microsoft         13.5
# 445    Microsoft         13.5
# 446    Microsoft         13.5
# 648    Microsoft         13.5

# %% [markdown]
# # 14-What is the average price of laptops in the dataset?

# %%
AVG = df["price_ln"].mean()

print('the AVG price of ALL_laptops is :',AVG)
# Out:
# the AVG price of ALL_laptops is : 15.886462827097459

# %% [markdown]
# # 15-How many laptop for each brand?

# %%
brand_counts = df['Manufacturer'].value_counts()

print(brand_counts)
# Out:
# Lenovo       220
# Dell         214
# HP           177
# Asus         118
# Acer          83
# Toshiba       38
# MSI           31
# Apple         16
# Samsung        8
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Chuwi          3
# Google         3
# LG             3
# Huawei         2
# Vero           2
# Fujitsu        2
# Razer          2
# Name: Manufacturer, dtype: int64

# %% [markdown]
# # 16-What is the most common brand of laptops in the dataset?

# %%
df['Manufacturer'].value_counts().nlargest(1)
# Out:
# Lenovo    220
# Name: Manufacturer, dtype: int64

# %%
sns.set(rc={'figure.figsize':[10,10]},font_scale=1.2)

sns.countplot(y='Manufacturer',data=df)
# Out:
# <Axes: xlabel='count', ylabel='Manufacturer'>

# %% [markdown]
# # 17-Is there any correlations between the laptop specifications (CPU, RAM, storage) and price?

# %%
df.corr()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10280\592014893.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              Screen Size       RAM    Weight       HDD       SSD    Hybrid  \
# Screen Size     1.000000  0.147854  0.841705  0.092823 -0.166241 -0.023367
# RAM             0.147854  1.000000  0.214142 -0.270311  0.532231 -0.033089
# Weight          0.841705  0.214142  1.000000  0.049455 -0.186438 -0.016055
# HDD             0.092823 -0.270311  0.049455  1.000000 -0.319280 -0.010118
# SSD            -0.166241  0.532231 -0.186438 -0.319280  1.000000 -0.034559
# Hybrid         -0.023367 -0.033089 -0.016055 -0.010118 -0.034559  1.000000
# FS             -0.196206 -0.051761 -0.168771 -0.047482 -0.162246 -0.005025
# price_ln       -0.025763  0.690319  0.011476 -0.240509  0.631585  0.006546
#
#                    FS  price_ln
# Screen Size -0.196206 -0.025763
# RAM         -0.051761  0.690319
# Weight      -0.168771  0.011476
# HDD         -0.047482 -0.240509
# SSD         -0.162246  0.631585
# Hybrid      -0.005025  0.006546
# FS           1.000000 -0.055034
# price_ln    -0.055034  1.000000

# %%
df.corr()['price_ln']
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10280\3196444011.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['price_ln']
# Screen Size   -0.025763
# RAM            0.690319
# Weight         0.011476
# HDD           -0.240509
# SSD            0.631585
# Hybrid         0.006546
# FS            -0.055034
# price_ln       1.000000
# Name: price_ln, dtype: float64

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10280\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # 18-Are there any outliers in the dataset with unusually high or low prices? If so, what might explain these outliers?
#
# we don't have any outliers

# %%
z_scores = np.abs((df['price_ln'] - df['price_ln'].mean()) / df['price_ln'].std())

outliers = df[z_scores > 3]

print(outliers)
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model Name, Category, Screen Size, Screen, CPU, RAM, GPU, Operating System, Operating System Version, Weight, HDD, SSD, Hybrid, FS, price_ln]
# Index: []

# %% [markdown]
# # 19-What are the least common operating systems used by the laptops in the dataset and how many times it found?

# %%
df['Operating System Version'].value_counts().nsmallest(1)
# Out:
# X    4
# Name: Operating System Version, dtype: int64

# %% [markdown]
# # 20-Are there any noticeable differences in price or specifications between laptops with different operating systems?

# %%
# group the laptops by operating system and calculate summary statistics
os_stats = df.groupby('Operating System Version').agg({'price_ln': ['count', 'mean', 'std'], 'RAM': ['mean', 'std']})

# print the summary statistics for each operating system
print(os_stats)
# Out:
#                          price_ln                             RAM
#                             count       mean       std       mean       std
# Operating System Version
# 10                            918  15.878716  0.578488   7.978214  3.932856
# 10 S                            8  16.022060  0.804644   7.000000  4.140393
# 7                               9  16.393616  0.297156   8.888889  4.371626
# X                               4  16.252140  0.345485  10.000000  4.000000

# %% [markdown]
# # 21-how many laptops that have specifications with (Model = HP && GPU = AMD Radeon 530) ?

# %%
filtered_df = df[(df['Manufacturer'] == 'HP') & (df['GPU'] == 'AMD Radeon 530')]

print(filtered_df[['Manufacturer', 'GPU']])
# Out:
#     Manufacturer             GPU
# 31            HP  AMD Radeon 530
# 99            HP  AMD Radeon 530
# 542           HP  AMD Radeon 530
# 555           HP  AMD Radeon 530
# 645           HP  AMD Radeon 530
# 676           HP  AMD Radeon 530
# 686           HP  AMD Radeon 530

# %% [markdown]
# # 22- How many models of laptops in dataset?

# %%
df['Manufacturer'].nunique()
# Out:
# 19

# %% [markdown]
# # 23-what are laptops that have No OS in their operating ?

# %%
filtered_df = df[(df['Operating System'] == 'No OS')]

print(filtered_df[['Manufacturer', 'Operating System']])
# Out:
#     Manufacturer Operating System
# 2             HP            No OS
# 10            HP            No OS
# 11            HP            No OS
# 17        Lenovo            No OS
# 21            HP            No OS
# 45        Lenovo            No OS
# 61        Lenovo            No OS
# 75        Lenovo            No OS
# 121       Lenovo            No OS
# 124           HP            No OS
# 135       Lenovo            No OS
# 137       Lenovo            No OS
# 141       Lenovo            No OS
# 171       Lenovo            No OS
# 182       Xiaomi            No OS
# 185       Lenovo            No OS
# 189       Xiaomi            No OS
# 190       Lenovo            No OS
# 200       Lenovo            No OS
# 207           HP            No OS
# 208       Lenovo            No OS
# 211       Lenovo            No OS
# 236         Asus            No OS
# 254       Lenovo            No OS
# 260       Lenovo            No OS
# 272       Lenovo            No OS
# 282       Lenovo            No OS
# 295       Lenovo            No OS
# 297       Lenovo            No OS
# 347       Lenovo            No OS
# 355       Lenovo            No OS
# 358       Lenovo            No OS
# 372       Lenovo            No OS
# 451       Lenovo            No OS
# 496       Lenovo            No OS
# 501       Xiaomi            No OS
# 513       Lenovo            No OS
# 532       Lenovo            No OS
# 575       Lenovo            No OS
# 607       Lenovo            No OS
# 623         Asus            No OS
# 633           HP            No OS
# 681       Lenovo            No OS
# 701       Lenovo            No OS
# 726         Asus            No OS
# 754       Lenovo            No OS
# 818           HP            No OS
# 827       Lenovo            No OS
# 831       Lenovo            No OS
# 839       Lenovo            No OS
# 898           HP            No OS
# 912       Lenovo            No OS

# %%
sns.countplot(x='Operating System',data=df)
# Out:
# <Axes: xlabel='Operating System', ylabel='count'>

# %% [markdown]
# # 24-what is the lap that has the high specifications ?

# %%
sorted_df = df.sort_values(by=['RAM', 'Weight'], ascending=[False, True])

best_laptop = sorted_df.iloc[0]

print("The laptop with the highest specifications is:")
print(best_laptop)
# Out:
# The laptop with the highest specifications is:
# Manufacturer                                           Asus
# Model Name                  G701VO-IH74K (i7-6820HK/32GB/2x
# Category                                             Gaming
# Screen Size                                            17.3
# Screen                          IPS Panel Full HD 1920x1080
# CPU                             Intel Core i7 6820HK 2.7GHz
# RAM                                                    32.0
# GPU                                 Nvidia GeForce GTX 980M
# Operating System                                    Windows
# Operating System Version                                 10
# Weight                                                 3.58
# HDD                                                       0
# SSD                                                     512
# Hybrid                                                    0
# FS                                                        0
# price_ln                                          16.246741
# Name: 868, dtype: object

# %% [markdown]
# # 25-How many model names laptops in the dataset ?

# %%
df['Model Name'].nunique()
# Out:
# 473

# %% [markdown]
# # 26-what is the 5 highest price?

# %%
df.nlargest(5, 'price_ln')
# Out:
#     Manufacturer      Model Name            Category  Screen Size  \
# 627        Razer       Blade Pro              Gaming         14.0
# 670       Lenovo     ThinkPad X1  2 in 1 Convertible         14.0
# 437    Microsoft  Surface Laptop           Ultrabook         13.5
# 825           HP  EliteBook x360  2 in 1 Convertible         13.3
# 3          Apple     MacBook Pro           Ultrabook         15.4
#
#                                  Screen                          CPU   RAM  \
# 627                   Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16.0
# 670               Touchscreen 2560x1440   Intel Core i7 7500U 2.7GHz   8.0
# 437               Touchscreen 2256x1504   Intel Core i7 7660U 2.5GHz  16.0
# 825     Full HD / Touchscreen 1920x1080   Intel Core i7 7600U 2.8GHz   8.0
# 3    IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz  16.0
#
#                               GPU Operating System Operating System Version  \
# 627       Nvidia GeForce GTX 1060          Windows                       10
# 670         Intel HD Graphics 620          Windows                       10
# 437  Intel Iris Plus Graphics 640          Windows                     10 S
# 825         Intel HD Graphics 620          Windows                       10
# 3              AMD Radeon Pro 455            macOS                       10
#
#      Weight  HDD  SSD  Hybrid  FS   price_ln
# 627    1.95    0  256       0   0  16.955789
# 670    1.42    0  256       0   0  16.952320
# 437    1.25    0  512       0   0  16.951934
# 825    1.28    0  256       0   0  16.940279
# 3      1.83    0  512       0   0  16.931822

# %%
df1 = df.nlargest(5, 'price_ln')
plt.boxplot(df1['price_ln'])
plt.title('Boxplot of Prices for Top 5 Laptops')
plt.ylabel('Price')
plt.show()
